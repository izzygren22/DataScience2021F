# %% [markdown]
# # Heatmap showing relationship between swear words and track number
# # Heatmap showing relationship between emotion words and track number
# # Vulgarity over time
# # Taylor Fav Number

# %% [markdown]
# ## Creating DataFrames for Each Album's Data

# %%
#import needed packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#debut
debut_filepath = '01-taylor_swift.csv'
debut_1 = pd.read_csv(debut_filepath)
#fearless
fearless_filepath = '02-fearless_taylors_version.csv'
fearless_2 = pd.read_csv(fearless_filepath)
#speak now
speak_now_filepath = '03-speak_now_deluxe_package.csv'
speak_now_3 = pd.read_csv(speak_now_filepath)
#red 
red_filepath = '04-red_deluxe_edition.csv'
red_4 = pd.read_csv(red_filepath)
#1989
_1989_filepath = '05-1989_deluxe.csv'
_1989_5 = pd.read_csv(_1989_filepath)
#reputation
reputation_filepath = '06-reputation.csv'
reputation_6 = pd.read_csv(reputation_filepath)
#lover
lover_filepath = '07-lover.csv'
lover_7 = pd.read_csv(lover_filepath)
#folklore
folklore_filepath = '08-folklore_deluxe_version.csv'
folklore_8 = pd.read_csv(folklore_filepath)
#evermore
evermore_filepath = '09-evermore_deluxe_version.csv'
evermore_9 = pd.read_csv(evermore_filepath)
evermore_9.head()
# Out:
#                   album_name track_title  track_n  \
# 0  evermore (deluxe version)      willow        1
# 1  evermore (deluxe version)      willow        1
# 2  evermore (deluxe version)      willow        1
# 3  evermore (deluxe version)      willow        1
# 4  evermore (deluxe version)      willow        1
#
#                                                lyric  line
# 0  I'm like the water when your ship rolled in th...     1
# 1  Rough on the surface, but you cut through like...     2
# 2                    And if it was an open-shut case     3
# 3  I never would've known from that look on your ...     4
# 4         Lost in your current like a priceless wine     5

# %% [markdown]
# ## Merging All the Ablum DataFrames into a Discography  DataFrame

# %%
ts_data = pd.concat([debut_1, fearless_2, speak_now_3, 
                            red_4, _1989_5, reputation_6,
                            lover_7, folklore_8, evermore_9])
ts_data
# Out:
#                     album_name       track_title  track_n  \
# 0                 Taylor Swift        Tim McGraw        1
# 1                 Taylor Swift        Tim McGraw        1
# 2                 Taylor Swift        Tim McGraw        1
# 3                 Taylor Swift        Tim McGraw        1
# 4                 Taylor Swift        Tim McGraw        1
# ..                         ...               ...      ...
# 907  evermore (deluxe version)  ​it’s time to go       17
# 908  evermore (deluxe version)  ​it’s time to go       17
# 909  evermore (deluxe version)  ​it’s time to go       17
# 910  evermore (deluxe version)  ​it’s time to go       17
# 911  evermore (deluxe version)  ​it’s time to go       17
#
#                                            lyric  line
# 0            He said the way my blue eyes shined     1
# 1    Put those Georgia stars to shame that night     2
# 2                         I said, "That's a lie"     3
# 3                    Just a boy in a Chevy truck     4
# 4           That had a tendency of gettin' stuck     5
# ..                                           ...   ...
# 907       You know, you know, you know, you know    50
# 908                         When it's time to go    51
# 909                               So then you go    52
# 910                                  Then you go    53
# 911                                  You just go    54
#
# [8358 rows x 5 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### A Fun Fact Before We Begin Data Cleaning!

# %%
ts_data['track_title'].nunique()
# Out:
# 163

# %% [markdown]
# Taylor Swift has as of Fearless (Taylor's Version) 163 songs!

# %% [markdown]
# #### Check for any reoccuring errors in data

# %%
ts_data['lyric'].value_counts()
# Out:
# Joeboy 'Sip (Alcohol)' Official Lyrics & Meaning | Verified    26
# Today was a fairytale                                          16
# Look what you just made me do                                  13
# (Eh, eh, eh, eh, eh)                                           12
# I'd never walk Cornelia Street again                           12
#                                                                ..
# Younger than my exes, but he act like such a man, so            1
# Hey, hey, hey                                                   1
# I'm still trying everything to get you laughing at me           1
# To fall in love with strangers, uh-uh, uh-uh                    1
# Come back and tell me why                                       1
# Name: lyric, Length: 5606, dtype: int64

# %% [markdown]
# #### Remove all occurences of "Joeboy 'Sip (Alcohol)' Official Lyrics & Meaning | Verified"

# %%
# Drop Line from Data Science Parichay
ts_data.drop(ts_data.index
             [ts_data['lyric'] == 
             "Joeboy 'Sip (Alcohol)' Official Lyrics & Meaning | Verified"],
             inplace=True)
# reset index
ts_data.reset_index(inplace=True)
del ts_data['index']
#check for occurences
ts_data.loc[ts_data.lyric == "Joeboy 'Sip (Alcohol)' Official Lyrics & Meaning | Verified"]
# Out:
# Empty DataFrame
# Columns: [album_name, track_title, track_n, lyric, line]
# Index: []

# %% [markdown]
# #### Switch Row from By Lyric to By Word

# %%
#turn each lyric entry from string to list of strings
ts_data = ts_data.assign(lyric =[lyric.split() for lyric in ts_data.lyric]) 
ts_data
# Out:
#                      album_name       track_title  track_n  \
# 0                  Taylor Swift        Tim McGraw        1
# 1                  Taylor Swift        Tim McGraw        1
# 2                  Taylor Swift        Tim McGraw        1
# 3                  Taylor Swift        Tim McGraw        1
# 4                  Taylor Swift        Tim McGraw        1
# ...                         ...               ...      ...
# 8131  evermore (deluxe version)  ​it’s time to go       17
# 8132  evermore (deluxe version)  ​it’s time to go       17
# 8133  evermore (deluxe version)  ​it’s time to go       17
# 8134  evermore (deluxe version)  ​it’s time to go       17
# 8135  evermore (deluxe version)  ​it’s time to go       17
#
#                                                   lyric  line
# 0          [He, said, the, way, my, blue, eyes, shined]     1
# 1     [Put, those, Georgia, stars, to, shame, that, ...     2
# 2                          [I, said,, "That's, a, lie"]     3
# 3                   [Just, a, boy, in, a, Chevy, truck]     4
# 4          [That, had, a, tendency, of, gettin', stuck]     5
# ...                                                 ...   ...
# 8131    [You, know,, you, know,, you, know,, you, know]    50
# 8132                         [When, it's, time, to, go]    51
# 8133                                [So, then, you, go]    52
# 8134                                    [Then, you, go]    53
# 8135                                    [You, just, go]    54
#
# [8136 rows x 5 columns]

# %%
flattened_col = pd.DataFrame([(index, word) for (index, words) in ts_data['lyric'].iteritems() for word in words],
                              columns=['index','word']).set_index('index') #Mr.Gorton
ts_words = ts_data.drop('lyric', axis='columns').join(flattened_col)
ts_words.reset_index(inplace = True, drop = True)
ts_words
# Out:
#                       album_name       track_title  track_n  line  word
# 0                   Taylor Swift        Tim McGraw        1     1    He
# 1                   Taylor Swift        Tim McGraw        1     1  said
# 2                   Taylor Swift        Tim McGraw        1     1   the
# 3                   Taylor Swift        Tim McGraw        1     1   way
# 4                   Taylor Swift        Tim McGraw        1     1    my
# ...                          ...               ...      ...   ...   ...
# 58069  evermore (deluxe version)  ​it’s time to go       17    53   you
# 58070  evermore (deluxe version)  ​it’s time to go       17    53    go
# 58071  evermore (deluxe version)  ​it’s time to go       17    54   You
# 58072  evermore (deluxe version)  ​it’s time to go       17    54  just
# 58073  evermore (deluxe version)  ​it’s time to go       17    54    go
#
# [58074 rows x 5 columns]

# %% [markdown]
# #### Get Rid of Special Characters Except ' and -

# %%
ts_words.loc[ts_words.word == "doin'"] # check for '
# Out:
#                         album_name                     track_title  track_n  \
# 6678   Fearless (Taylor’s Version)  Tell Me Why (Taylor’s Version)        8
# 6781   Fearless (Taylor’s Version)  Tell Me Why (Taylor’s Version)        8
# 6872   Fearless (Taylor’s Version)  Tell Me Why (Taylor’s Version)        8
# 35191                   reputation                  Don’t Blame Me        4
# 35284                   reputation                  Don’t Blame Me        4
# 35316                   reputation                  Don’t Blame Me        4
# 35417                   reputation                  Don’t Blame Me        4
# 35449                   reputation                  Don’t Blame Me        4
# 35548                   reputation                  Don’t Blame Me        4
# 35578                   reputation                  Don’t Blame Me        4
# 35583                   reputation                  Don’t Blame Me        4
# 37084                   reputation                        Gorgeous        8
# 39824                   reputation           Call It What You Want       14
#
#        line   word
# 6678     13  doin'
# 6781     27  doin'
# 6872     41  doin'
# 35191     2  doin'
# 35284    16  doin'
# 35316    20  doin'
# 35417    33  doin'
# 35449    37  doin'
# 35548    52  doin'
# 35578    56  doin'
# 35583    56  doin'
# 37084     7  doin'
# 39824     6  doin'

# %%
ts_words.loc[ts_words.word == "yeah?)"] #check for Special Characters
# Out:
#                album_name          track_title  track_n  line    word
# 16849  Speak Now (Deluxe)  Better Than Revenge       10    56  yeah?)

# %%
ts_words['word'] = ts_words.word.str.replace(r"[();:,.?""]",'') # changing regular expresion, this warning is okay
# Out:
# <ipython-input-10-185ab78c0d8d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ts_words['word'] = ts_words.word.str.replace(r"[();:,.?""]",'') # changing regular expresion, this warning is okay

# %%
ts_words.loc[6678] # check for '
# Out:
# album_name        Fearless (Taylor’s Version)
# track_title    Tell Me Why (Taylor’s Version)
# track_n                                     8
# line                                       13
# word                                    doin'
# Name: 6678, dtype: object

# %%
ts_words.loc[16849] #check for Special Characters
# Out:
# album_name      Speak Now (Deluxe)
# track_title    Better Than Revenge
# track_n                         10
# line                            56
# word                          yeah
# Name: 16849, dtype: object

# %% [markdown]
# #### Switch to All Lowercase

# %%
ts_words['word'] = ts_words['word'].str.lower()

# %%
ts_words #check for all lowercase
# Out:
#                       album_name       track_title  track_n  line  word
# 0                   Taylor Swift        Tim McGraw        1     1    he
# 1                   Taylor Swift        Tim McGraw        1     1  said
# 2                   Taylor Swift        Tim McGraw        1     1   the
# 3                   Taylor Swift        Tim McGraw        1     1   way
# 4                   Taylor Swift        Tim McGraw        1     1    my
# ...                          ...               ...      ...   ...   ...
# 58069  evermore (deluxe version)  ​it’s time to go       17    53   you
# 58070  evermore (deluxe version)  ​it’s time to go       17    53    go
# 58071  evermore (deluxe version)  ​it’s time to go       17    54   you
# 58072  evermore (deluxe version)  ​it’s time to go       17    54  just
# 58073  evermore (deluxe version)  ​it’s time to go       17    54    go
#
# [58074 rows x 5 columns]

# %% [markdown]
# ### Yay, We Finished the Data Cleaning!!!

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Heatmap showing relationship between swear words and track number

# %% [markdown]
# ###### Some Background for the Uncool People:
# Taylor Swift is know for her Track 5s.  The Track 5 of every album is always the most emotional and vulnerable track of the ablum. Let's see if this is actually true by looking at the corralation between the number of swear words and track number!

# %%
swears = ['gosh', 'god', 'darn', 'damn', 'ass','asshole','shit', 'bitches', 'bitch', 'fuck', 'fucking', 'fucked']

# %%
#heatmap of Number of Swears words per track number, by album
swr_data = ts_words['word'].isin(swears).to_frame()
swr_data = swr_data.loc[:, ]
swr_data
# ts_data.drop('lyric', axis='columns').join(flattened_col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f11f16c10e6e> in <module>
#       1 #heatmap of Number of Swears words and track number, by album
#       2 swr_data = ts_words['word'].isin(swears).to_frame()
# ----> 3 swr_data = swr_data.query('word' == True)
#       4 swr_data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3464         if not isinstance(expr, str):
#    3465             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 3466             raise ValueError(msg)
#    3467         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3468         kwargs["target"] = None
#
# ValueError: expr must be a string to be evaluated, <class 'bool'> given

# %% [markdown]
# ### Heatmap showing relationship between swear words and track number
# ### Heatmap showing relationship between emotion words and track number
# ### Vulgarity over time
# ### Taylor Fav Number
